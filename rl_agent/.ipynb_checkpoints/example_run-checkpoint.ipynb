# %% [markdown]
# ### Example: Walk-Forward Portfolio Optimization

# %%
"""
Demonstration of the rolling-window strategy.
"""

import numpy as np
import pandas as pd

import os
os.chdir("..")

# from rl_agent.config import (
#    Config, 
#    EnvironmentConfig, FeatureConfig, 
#    NetworkConfig, TrainingConfig, BacktestConfig
# )
from rl_agent.fin_data import download_fin_data, get_sp500
from rl_agent.forwardbacktest import WalkForwardBacktestEngine
from rl_agent.universe import DynamicUniverse
from rl_agent.utils import (
    compute_portfolio_metrics,
    format_metrics,
    generate_realistic_universe
)

# %% [markdown]
# ### Obtain data for S&P 500 stocks (replace with your own data loading if needed)

# %%
ticker, sp500 = get_sp500()
# _, _, prices = download_fin_data(start_date = "2014-01-01", end_date="2015-12-31", ticker=ticker, sp500=sp500)
# Store returns:
# pd.DataFrame(prices.pct_change()).to_csv("C:\\Users\\lukas\\Downloads\\returns.csv")
# pd.DataFrame(prices).to_csv("C:\\Users\\lukas\\Downloads\\prices.csv")
prices = pd.read_csv("C:\\Users\\lukas\\Downloads\\prices.csv", index_col=0, parse_dates=True)
# Out:
# date       str
# tickers    str
# dtype: object
# 1194

# %%
# Initialize backtest engine
engine = WalkForwardBacktestEngine(prices)

# %%
periods = engine._get_periods()

# %%
train_start_date, train_end_date, oos_start_date, oos_end_date = periods[0]

# %%
active_mask = np.zeros(prices.shape[1], dtype=bool)
active_mask[:prices.shape[1]] = ~prices.isna().loc[oos_start_date].values

# %%
# Extract training data (handle NaN for missing data)
window_prices = prices.loc[train_start_date:train_end_date].copy()

# %%
# Extract training data (handle NaN for missing data)
window_prices = prices.loc[train_start_date:train_end_date].copy()
# Forward-fill then backward-fill such that we have no NaN for feature computation, 
# but returns will be 0 for inactive periods (before listing/after delisting)
window_prices = window_prices.ffill().bfill()
# If any column is entirely NaN, fill with a constant to avoid computation errors
for col in window_prices.columns:
    if window_prices[col].isna().all():
        window_prices[col] = 100.0  # Placeholder, will be masked

# %%
from rl_agent.features import FeatureConstructor
from rl_agent.config import FeatureConfig

# %%
feature_engine = FeatureConstructor(window_prices, FeatureConfig())

# %%
def _build_rebalance_schedule2() -> list[int]:
    dates = window_prices.index
    start_idx = feature_engine.valid_start_idx
    
    # Slice den Index ab dem validen Startpunkt
    relevant_dates = dates[start_idx:]
    
    # Finde Indizes, bei denen der Monat des aktuellen Tages != Monat des nächsten Tages ist
    change_mask = relevant_dates[:-1].month != relevant_dates[1:].month

    # Indizes der Wechsel finden (relativ zum start_idx)
    rebalance_indices = np.where(change_mask)[0] + start_idx
    
    # Letzten Index und Start-Index hinzufügen
    last_idx = len(dates) - 1
    result = np.unique(np.concatenate([[start_idx], rebalance_indices, [last_idx]]))
    
    return result.astype(int).tolist()

# %%
ri2 = _build_rebalance_schedule2()

# %%
step_idx = ri2[0]

# %%
features = feature_engine.get_state_features(step_idx)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 features = feature_engine.get_state_features(step_idx)
#
# NameError: name 'step_idx' is not defined

# %%
from rl_agent.environment import PortfolioEnv
from rl_agent.config import Config, EnvironmentConfig, FeatureConfig, NetworkConfig, TrainingConfig, BacktestConfig

# %%
train_env = PortfolioEnv(window_prices, target_returns=EnvironmentConfig().target_returns, 
                         env_config=EnvironmentConfig(), feature_config=FeatureConfig())

# %%
rd = train_env._build_rebalance_schedule()

# %%
step_idx = rd[0]

# %%
agent, train_info = engine._train_window(window_prices, active_mask, 0)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 agent, train_info = engine._train_window(window_prices, active_mask, 0)
#
# File c:\Users\lukas\OneDrive\Dokumente\Projects\Reinforcement Learning Optimization\rl_agent\forwardbacktest.py:319, in WalkForwardBacktestEngine._train_window(self, train_prices, active_mask, window_idx)
#     315 episode_rewards = []
#     317 for ep in range(1, train_config.n_episodes + 1):
#     318     # Collect rollout
# --> 319     flat_state, stock_feats, market_feats = train_env.reset()
#     320     total_reward = 0.0
#     321     done = False
#
# File c:\Users\lukas\OneDrive\Dokumente\Projects\Reinforcement Learning Optimization\rl_agent\environment.py:93, in PortfolioEnv.reset(self)
#      90 self._portfolio_values = [1.0]  # Start with unit value
#      91 self._trade_history = []
# ---> 93 return self._get_state()
#
# File c:\Users\lukas\OneDrive\Dokumente\Projects\Reinforcement Learning Optimization\rl_agent\environment.py:274, in PortfolioEnv._get_state(self)
#     272 """Build state from features and current weights."""
#     273 # Flat state: features + current weights
# --> 274 features = self.feature_engine.get_state_features(self._step_idx)
#     275 flat_state = np.concatenate([features, self._current_weights])
#     277 # Per-stock features for attention: (n_stocks, n_features_per_stock + 1)
#
# File c:\Users\lukas\OneDrive\Dokumente\Projects\Reinforcement Learning Optimization\rl_agent\features.py:44, in FeatureConstructor.get_state_features(self, date_idx)
#      42 state_features = []
#      43 for _, df in self._features.items():
# ---> 44     row = df.iloc[date_idx].values
#      45     state_features.append(row)
#      46 return np.concatenate(state_features).astype(np.float32)
#
# File c:\ProgramData\anaconda3\envs\ptenv\Lib\site-packages\pandas\core\indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# -> 1207 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\ProgramData\anaconda3\envs\ptenv\Lib\site-packages\pandas\core\indexing.py:1773, in _iLocIndexer._getitem_axis(self, key, axis)
#    1770     raise TypeError("Cannot index by location index with a non-integer key")
#    1772 # validate the location
# -> 1773 self._validate_integer(key, axis)
#    1775 return self.obj._ixs(key, axis=axis)
#
# File c:\ProgramData\anaconda3\envs\ptenv\Lib\site-packages\pandas\core\indexing.py:1706, in _iLocIndexer._validate_integer(self, key, axis)
#    1704 len_axis = len(self.obj._get_axis(axis))
#    1705 if key >= len_axis or key < -len_axis:
# -> 1706     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %%
# Run walk-forward optimization
results = engine.run()
# Out:
# ==================================================
# Reinforcement Learning Portfolio Optimization
# ==================================================
# Dynamic Universe Summary:
#   Total unique stocks:        818
#   Max concurrent stocks:      500
#   Min concurrent stocks:      188
#   Mean concurrent stocks:     338
#   Entrants:                   474
#   Delistings:                 162
#   Date range:                 1996-01-02 to 2026-01-30
#   Data size:                  818
#   Train window:     5.0 years
#   Warm-start:       True
#   Episodes/window:  200
# ==================================================
#
# --- Window 1/285 ---
#   Train: 1996-01-02 00:00:00 → 2000-10-31 00:00:00
#   OOS:   2000-11-01 00:00:00 → 2000-11-30 00:00:00
#   Active stocks: 246
# OOS start index: 244 OOS start date: 2000-11-01 00:00:00
# OOS return: +nan | OOS raw return: +nan | Train time: 336.2s | Episodes: 130
#
# --- Window 2/285 ---
#   Train: 1996-02-01 00:00:00 → 2000-11-30 00:00:00
#   OOS:   2000-12-01 00:00:00 → 2000-12-29 00:00:00
#   Active stocks: 248
# OOS start index: 244 OOS start date: 2000-12-01 00:00:00
# OOS return: +nan | OOS raw return: +nan | Train time: 249.7s | Episodes: 123
#
# --- Window 3/285 ---
#   Train: 1996-03-01 00:00:00 → 2000-12-29 00:00:00
#   OOS:   2001-01-02 00:00:00 → 2001-01-31 00:00:00
#   Active stocks: 251
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Run walk-forward optimization
# ----> 2 results = engine.run()
#
# File c:\Users\lukas\OneDrive\Dokumente\Projects\Reinforcement Learning Optimization\rl_agent\forwardbacktest.py:156, in WalkForwardBacktestEngine.run(self)
#     151 # window_prices.fillna(0.0, inplace=True) # Alternatively, fill with 0.0
#     152 # if we want features to reflect missing data more directly (e.g. 0 return before IPO)
#     153
#     154 # Train the agent on this window
#     155 window_start = time.time()
# --> 156 agent, train_info = self._train_window(window_prices, active_mask, i)
#     157 train_time = time.time() - window_start
#     159 # Get deterministic action (weights) from trained agent
#
# File c:\Users\lukas\OneDrive\Dokumente\Projects\Reinforcement Learning Optimization\rl_agent\forwardbacktest.py:328, in WalkForwardBacktestEngine._train_window(self, train_prices, active_mask, window_idx)
#     325 # Apply universe mask to action before stepping
#     326 action[~active_mask[: len(action)]] = -1e6  # Will be zeroed by softmax/processing
# --> 328 result = train_env.step(action)
#     330 agent.store_transition(
#     331     Transition(
#     332         stock_features=stock_feats,
#    (...)    339     )
#     340 )
#     342 stock_feats = result.stock_features
#
# File c:\Users\lukas\OneDrive\Dokumente\Projects\Reinforcement Learning Optimization\rl_agent\environment.py:226, in PortfolioEnv.step(self, action)
#     224     obs = self._get_state()  # Terminal state (won't be used)
#     225 else:
# --> 226     obs = self._get_state()
#     228 return StepResult(
#     229     state=obs[0],
#     230     stock_features=obs[1],
#    (...)    234     info=info,
#     235 )
#
# File c:\Users\lukas\OneDrive\Dokumente\Projects\Reinforcement Learning Optimization\rl_agent\environment.py:278, in PortfolioEnv._get_state(self)
#     275 flat_state = np.concatenate([features, self._current_weights])
#     277 # Per-stock features for attention: (n_stocks, n_features_per_stock + 1)
# --> 278 stock_features = self.feature_engine.get_stock_features(self._step_idx)
#     279 stock_features = np.hstack(
#     280     [stock_features, self._current_weights.reshape(-1, 1)]
#     281 )
#     283 # Market features
#
# File c:\Users\lukas\OneDrive\Dokumente\Projects\Reinforcement Learning Optimization\rl_agent\features.py:61, in FeatureConstructor.get_stock_features(self, date_idx)
#      58         per_stock_features.append(df.iloc[date_idx].values.reshape(-1, 1))
#      60 # Stack per-stock features: (n_stocks, n_per_stock_features)
# ---> 61 stock_features = np.hstack(per_stock_features).astype(np.float32)
#      62 return stock_features
#
# File c:\ProgramData\anaconda3\envs\ptenv\Lib\site-packages\numpy\_core\shape_base.py:367, in hstack(tup, dtype, casting)
#     365     return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#     366 else:
# --> 367     return _nx.concatenate(arrs, 1, dtype=dtype, casting=casting)
#
# KeyboardInterrupt:

# %%
returns = prices.pct_change().fillna(0)
period_returns = []
active_mask = pd.DataFrame()  
    # for r in results["window_results"]:
    #    period_ret = returns.loc[r.oos_start:r.oos_end]
    #    active = r.active_mask[: prices.shape[1]]
    #    ew_daily = period_ret.iloc[:, active].mean(axis=1)
    #    bm_returns.append(np.prod(1 + ew_daily.values) - 1)
    # for r in results["window_results"]:
    #    start = prices.index.get_indexer([r.oos_start], method="ffill")[0]
    #    end = prices.index.get_indexer([r.oos_end], method="ffill")[0]
    #    period_ret = prices.iloc[start:end + 1].pct_change().fillna(0)
    #    active = r.active_mask[: prices.shape[1]]
    #    ew_daily = period_ret.iloc[:, active].mean(axis=1).values
    #    bm_returns.append(np.prod(1 + ew_daily) - 1)
for r in results["window_results"]:
    active_mask = pd.concat([active_mask, pd.DataFrame([r.active_mask])])
    period_df = returns.loc[r.oos_start:r.oos_end]
    period_returns.append((1 + period_df).prod() - 1)

masked_returns = pd.DataFrame(period_returns).where(active_mask.values, np.nan)
bm_values = np.cumprod(np.concatenate([[1.0], 1 + np.array(masked_returns)]))

bm_metrics = compute_portfolio_metrics(bm_values)
print(format_metrics(bm_metrics))
